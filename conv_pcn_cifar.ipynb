# %% [markdown]
# **Ariel Pan, Daniel Lyu**
#
# Spring 2026
#
# CS 443: Bio-inspired Machine Learning
#
# Project 2: Predictive Coding
#
# #### Week 4: Train ConvPCNs on CIFAR-10
#
# The focus of this week is to train several ConvPCN nets and analyze the effect of He/Kaiming initialization and Group Normalization. Finally, you will train a deeper ConvPCN to strive for high classification accuracy on CIFAR-10 🚀.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)


plt.style.use(['seaborn-v0_8-colorblind', 'seaborn-v0_8-darkgrid'])
plt.show()
plt.rcParams.update({'font.size': 18})

np.set_printoptions(suppress=True, precision=3)

# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
project_path = '/content/drive/MyDrive/ColabNotebooks/project2'
os.chdir(project_path)

# %% [markdown]
# ## Task 9: The effect of weight initialization and GroupNorm when training ConvPCN on CIFAR-10
#
# Now we are ready to build a convolutional PC network and train it on CIFAR-10! 🎉 Woohoo 🎉!!

# %%
from conv_pcn import ConvPCN6Mini

# %% [markdown]
# ### 9a. Build and test `ConvPC6Mini`
#
# Let's build and test a PCN that we will call `ConvPCN6Mini` in `conv_pcn.py` with:
# - 1 solo `Conv2D` layer at the start of the network
# - 3 ConvPCNBlocks
# - 1 dense hidden layer
# - 1 output layer
#
# See the class docstring for specifics.

# %% [markdown]
# #### Test: Print network architecture

# %%
pcnet = ConvPCN6Mini(input_feats_shape=(32, 32, 3), C=5, dropout_rate=None, wt_init='he')
pcnet.compile()
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(Dense_output) shape: [1, 5]
# Dense layer output(Dense_hidden) shape: [1, 128]
# Flatten layer output(Flatten) shape: [1, 3072]
# MaxPool2D layer output(MaxPool_2) shape: [1, 4, 4, 192]
# PCNBlock_2:
# 	Conv2DTranspose layer output(PCNBlock_2_convT) shape: [1, 8, 8, 128]
# 	Conv2D layer output(PCNBlock_2_conv) shape: [1, 8, 8, 192]
# MaxPool2D layer output(MaxPool_1) shape: [1, 8, 8, 128]
# PCNBlock_1:
# 	Conv2DTranspose layer output(PCNBlock_1_convT) shape: [1, 16, 16, 64]
# 	Conv2D layer output(PCNBlock_1_conv) shape: [1, 16, 16, 128]
# MaxPool2D layer output(MaxPool_0) shape: [1, 16, 16, 64]
# PCNBlock_0:
# 	Conv2DTranspose layer output(PCNBlock_0_convT) shape: [1, 32, 32, 64]
# 	Conv2D layer output(PCNBlock_0_conv) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D_init) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------

# %% [markdown]
# You should see the following above:
#
# ```
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 5]
# Dense layer output(Dense_Hidden) shape: [1, 128]
# Dropout layer output(Dropout) shape: [1, 3072]
# Flatten layer output(Flatten) shape: [1, 3072]
# MaxPool2D layer output(Maxpool2D_2) shape: [1, 4, 4, 192]
# PCNBlock_2:
# 	Conv2D layer output(FFConv2D) shape: [1, 8, 8, 192]
# 	Conv2DTranspose layer output(FBConv2D) shape: [1, 8, 8, 128]
# MaxPool2D layer output(Maxpool2D_1) shape: [1, 8, 8, 128]
# PCNBlock_1:
# 	Conv2D layer output(FFConv2D) shape: [1, 16, 16, 128]
# 	Conv2DTranspose layer output(FBConv2D) shape: [1, 16, 16, 64]
# MaxPool2D layer output(Maxpool2D_0) shape: [1, 16, 16, 64]
# PCNBlock_0:
# 	Conv2D layer output(FFConv2D) shape: [1, 32, 32, 64]
# 	Conv2DTranspose layer output(FBConv2D) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# ```

# %% [markdown]
# #### Overfit test
#
# Download the CIFAR-10 dev set from the project website and run the code below to load it in. *The dev set is already preprocessed so it should be ready for use.*
#
# To test whether your net is working properly, we will perform an overfit test on a small amount of the CIFAR-10 data. Train your `ConvPCN6Mini` on the dev set with default hyperparameters except for:
# - `50` epochs
# - Group norm and He initialization turned on.
# - Set the mini-batch size accordingly...
#
# Make a plot showing the training loss over epochs. If your net is working properly, you should see the loss plummet to ≤0.05 within the 50 epochs.
#
# **Note:** If your code assumes a val set is present, set the dev set also as the val set for this test.

# %%
# KEEP ME
cifar_dev = np.load('data/cifar10_dev.npz')
x_dev = tf.constant(cifar_dev['x_dev'], dtype=tf.float32)
y_dev = tf.constant(cifar_dev['y_dev'], dtype=tf.int32)
print('CIFAR-10 dev set info:')
print(f'{x_dev.shape=} {y_dev.shape=}')
print(f'{x_dev.dtype=} {y_dev.dtype=}')
# Out:
# CIFAR-10 dev set info:
# x_dev.shape=TensorShape([20, 32, 32, 3]) y_dev.shape=TensorShape([20])
# x_dev.dtype=tf.float32 y_dev.dtype=tf.int32

# %%
X_small = x_dev
y_small = y_dev
pcnet2 = ConvPCN6Mini(
    input_feats_shape=(32, 32, 3),
    C=10,
    wt_init='he',
    do_group_norm=True
)
pcnet2.compile()
for layer in pcnet.layers:
    if hasattr(layer, 'set_mode'):
        layer.set_mode(True)
loss_history = pcnet2.fit(
    X_small,
    y_small,
    X_small,
    y_small,
    batch_size=10,
    max_epochs=50,
)
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(Dense_output) shape: [1, 10]
# Dense layer output(Dense_hidden) shape: [1, 128]
# Dropout layer output(Dropout) shape: [1, 3072]
# Flatten layer output(Flatten) shape: [1, 3072]
# MaxPool2D layer output(MaxPool_2) shape: [1, 4, 4, 192]
# PCNBlock_2:
# 	Conv2DTranspose layer output(PCNBlock_2_convT) shape: [1, 8, 8, 128]
# 	Conv2D layer output(PCNBlock_2_conv) shape: [1, 8, 8, 192]
# MaxPool2D layer output(MaxPool_1) shape: [1, 8, 8, 128]
# PCNBlock_1:
# 	Conv2DTranspose layer output(PCNBlock_1_convT) shape: [1, 16, 16, 64]
# 	Conv2D layer output(PCNBlock_1_conv) shape: [1, 16, 16, 128]
# MaxPool2D layer output(MaxPool_0) shape: [1, 16, 16, 64]
# PCNBlock_0:
# 	Conv2DTranspose layer output(PCNBlock_0_convT) shape: [1, 32, 32, 64]
# 	Conv2D layer output(PCNBlock_0_conv) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D_init) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Epoch 1/50 | Time : 11.39 s | train_loss: 13.1699 | val_loss: 21.7611 | val_acc: 0.3000
#
# Epoch 2/50 | Time : 0.06 s | train_loss: 17.2922 | val_loss: 19.7631 | val_acc: 0.2000
#
# Epoch 3/50 | Time : 0.06 s | train_loss: 21.1049 | val_loss: 13.1312 | val_acc: 0.2500
#
# Epoch 4/50 | Time : 0.06 s | train_loss: 10.2663 | val_loss: 12.8008 | val_acc: 0.4500
#
# Epoch 5/50 | Time : 0.06 s | train_loss: 12.2249 | val_loss: 9.9252 | val_acc: 0.5000
#
# Epoch 6/50 | Time : 0.06 s | train_loss: 9.2175 | val_loss: 6.6881 | val_acc: 0.2000
#
# Epoch 7/50 | Time : 0.06 s | train_loss: 11.0462 | val_loss: 7.2327 | val_acc: 0.2000
#
# Epoch 8/50 | Time : 0.06 s | train_loss: 9.3514 | val_loss: 5.1307 | val_acc: 0.5500
#
# Epoch 9/50 | Time : 0.06 s | train_loss: 7.4035 | val_loss: 6.1723 | val_acc: 0.4000
#
# Epoch 10/50 | Time : 0.06 s | train_loss: 4.7478 | val_loss: 5.8639 | val_acc: 0.5000
#
# Epoch 11/50 | Time : 0.06 s | train_loss: 7.2766 | val_loss: 4.9710 | val_acc: 0.7500
#
# Epoch 12/50 | Time : 0.07 s | train_loss: 0.9810 | val_loss: 4.8177 | val_acc: 0.7500
#
# Epoch 13/50 | Time : 0.06 s | train_loss: 2.8043 | val_loss: 4.7700 | val_acc: 0.7500
#
# Epoch 14/50 | Time : 0.06 s | train_loss: 5.2314 | val_loss: 5.1144 | val_acc: 0.6000
#
# Epoch 15/50 | Time : 0.06 s | train_loss: 8.3094 | val_loss: 4.4365 | val_acc: 0.8500
#
# Epoch 16/50 | Time : 0.06 s | train_loss: 6.5259 | val_loss: 4.2134 | val_acc: 0.8500
#
# Epoch 17/50 | Time : 0.06 s | train_loss: 0.1499 | val_loss: 4.2546 | val_acc: 0.7500
#
# Epoch 18/50 | Time : 0.06 s | train_loss: 4.4538 | val_loss: 4.1775 | val_acc: 0.7000
#
# Epoch 19/50 | Time : 0.06 s | train_loss: 0.8643 | val_loss: 3.8722 | val_acc: 0.8000
#
# Epoch 20/50 | Time : 0.06 s | train_loss: 0.3479 | val_loss: 3.7520 | val_acc: 0.8500
#
# Epoch 21/50 | Time : 0.06 s | train_loss: 3.6900 | val_loss: 3.7481 | val_acc: 0.9000
#
# Epoch 22/50 | Time : 0.07 s | train_loss: 0.2054 | val_loss: 3.8029 | val_acc: 0.8500
#
# Epoch 23/50 | Time : 0.06 s | train_loss: 1.9154 | val_loss: 3.8304 | val_acc: 0.8500
#
# Epoch 24/50 | Time : 0.06 s | train_loss: 5.7599 | val_loss: 3.7855 | val_acc: 0.8500
#
# Epoch 25/50 | Time : 0.06 s | train_loss: 3.7863 | val_loss: 3.7076 | val_acc: 0.9000
#
# Epoch 26/50 | Time : 0.06 s | train_loss: 0.0740 | val_loss: 3.6955 | val_acc: 0.9000
#
# Epoch 27/50 | Time : 0.06 s | train_loss: 1.8607 | val_loss: 3.6938 | val_acc: 0.9000
#
# Epoch 28/50 | Time : 0.06 s | train_loss: 1.8628 | val_loss: 3.6945 | val_acc: 0.9000
#
# Epoch 29/50 | Time : 0.06 s | train_loss: 7.3880 | val_loss: 3.6915 | val_acc: 0.9000
#
# Epoch 30/50 | Time : 0.06 s | train_loss: 0.0018 | val_loss: 3.6901 | val_acc: 0.9000
#
# Epoch 31/50 | Time : 0.06 s | train_loss: 5.5265 | val_loss: 3.6894 | val_acc: 0.9000
#
# Epoch 32/50 | Time : 0.06 s | train_loss: 0.0241 | val_loss: 3.6859 | val_acc: 0.9000
#
# Epoch 33/50 | Time : 0.06 s | train_loss: 3.6859 | val_loss: 3.6847 | val_acc: 0.9000
#
# Epoch 34/50 | Time : 0.07 s | train_loss: 0.0021 | val_loss: 3.6850 | val_acc: 0.9000
#
# Epoch 35/50 | Time : 0.06 s | train_loss: 1.8441 | val_loss: 3.6855 | val_acc: 0.9000
#
# Epoch 36/50 | Time : 0.06 s | train_loss: 5.5277 | val_loss: 3.6860 | val_acc: 0.9000
#
# Epoch 37/50 | Time : 0.06 s | train_loss: 7.3739 | val_loss: 3.6859 | val_acc: 0.9000
#
# Epoch 38/50 | Time : 0.06 s | train_loss: 5.5289 | val_loss: 3.6855 | val_acc: 0.9000
#
# Epoch 39/50 | Time : 0.06 s | train_loss: 7.4649 | val_loss: 3.6843 | val_acc: 0.9000
#
# Epoch 40/50 | Time : 0.06 s | train_loss: 3.6843 | val_loss: 3.6845 | val_acc: 0.9000
#
# Epoch 41/50 | Time : 0.06 s | train_loss: 0.0027 | val_loss: 3.6853 | val_acc: 0.9000
#
# Epoch 42/50 | Time : 0.06 s | train_loss: 1.8432 | val_loss: 3.6878 | val_acc: 0.9000
#
# Epoch 43/50 | Time : 0.07 s | train_loss: 1.8423 | val_loss: 3.6938 | val_acc: 0.9000
#
# Epoch 44/50 | Time : 0.06 s | train_loss: 1.9678 | val_loss: 3.6851 | val_acc: 0.9000
#
# Epoch 45/50 | Time : 0.06 s | train_loss: 3.6856 | val_loss: 3.6845 | val_acc: 0.9000
#
# Epoch 46/50 | Time : 0.06 s | train_loss: 1.8476 | val_loss: 3.6846 | val_acc: 0.9000
#
# Epoch 47/50 | Time : 0.06 s | train_loss: 3.7339 | val_loss: 3.6843 | val_acc: 0.9000
#
# Epoch 48/50 | Time : 0.06 s | train_loss: 1.8487 | val_loss: 3.6843 | val_acc: 0.9000
#
# Epoch 49/50 | Time : 0.07 s | train_loss: 0.0017 | val_loss: 3.6844 | val_acc: 0.9000
#
# Epoch 50/50 | Time : 0.06 s | train_loss: 3.6852 | val_loss: 3.6849 | val_acc: 0.9000
#
# Finished training after 50 epochs!

# %%
plt.plot(loss_history[0])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('ConvPCN Overfit Test')
plt.show()

# %% [markdown]
# ### 9b. Weight initialization and group norm CIAR-10 experiment
#
# Let's run an experiment to see how the different weight initialization strategies (`'normal'` vs `'he'`) and group norm components of the model affect classification accuracy and speed of learning when training on CIFAR-10.
#
# Train `ConvPC6Mini` with the following 3 configurations below:
# 1. Normal weight initialization, no group norm
# 2. He weight initialization, no group norm
# 3. He weight initialization, group norm
#
# Make 3 high-quality plots to summarize the results of the simulation experiment:
# 1. training loss over epochs for the 3 nets.
# 2. val loss over epochs for the 3 nets.
# 3. val accuracy over epochs for the 3 nets.
#
# Use default hyperparameters to train each of your networks except for:
# - `30` training epochs.
# - learning rate of `1e-4` (or try `1e-5` if network #2 does not make any training progress).
#
# **Note:**
# - When you import CIFAR-10, use the default `'global'` normalization approach.
# - Remember that we are now training a CNN so you do NOT want to draw on the flattened features.
# - Each network should take 5-10 minutes to train on the GPU.

# %%
import sys

sys.path.append("/content/drive/MyDrive/ColabNotebooks/CS446_Project2")

# %%
from image_datasets import get_dataset, train_val_split

x_train, y_train, x_test, y_test = get_dataset('cifar10',flatten=False)
# Out:
# x_train shape: (50000, 32, 32, 3), dtype: <dtype: 'float32'>
# y_train shape: (50000,), dtype: <dtype: 'int32'>
# x_test shape: (10000, 32, 32, 3), dtype: <dtype: 'float32'>
# y_test shape: (10000,), dtype: <dtype: 'int32'>

# %%
x_train,y_train,x_val,y_val = train_val_split(x_train,y_train)
print(x_train.shape)
# Out:
# (45000, 32, 32, 3)

# %%
configs = [
    {"name": "normal_no_gn", "init": "normal", "group_norm": False},
    {"name": "he_no_gn", "init": "he", "group_norm": False},
    {"name": "he_gn", "init": "he", "group_norm": True},
]

# %%
def train_model(init_type, use_group_norm):
    model = ConvPCN6Mini(
        input_feats_shape=x_train.shape[1:],
        C=10,
        wt_init=init_type,
        do_group_norm=use_group_norm,
    )
    model.compile(lr = 1e-4)
    train_loss, val_loss, val_acc, _ = model.fit(
        x_train, y_train,
        x_val, y_val,
        batch_size=256,
        max_epochs=30,
    )

    return train_loss, val_loss, val_acc

# %%
results = {}

# normal_no_gn
cfg0 = configs[0]
print("Training: normal_no_gn")

train_loss0, val_loss0, val_acc0 = train_model(
    cfg0["init"],
    cfg0["group_norm"]
)

results["normal_no_gn"] = {
    "train_loss": train_loss0,
    "val_loss": val_loss0,
    "val_acc": val_acc0,
}
# Out:
# Training: normal_no_gn
# ---------------------------------------------------------------------------
# Dense layer output(Dense_output) shape: [1, 10]
# Dense layer output(Dense_hidden) shape: [1, 128]
# Dropout layer output(Dropout) shape: [1, 3072]
# Flatten layer output(Flatten) shape: [1, 3072]
# MaxPool2D layer output(MaxPool_2) shape: [1, 4, 4, 192]
# PCNBlock_2:
# 	Conv2DTranspose layer output(PCNBlock_2_convT) shape: [1, 8, 8, 128]
# 	Conv2D layer output(PCNBlock_2_conv) shape: [1, 8, 8, 192]
# MaxPool2D layer output(MaxPool_1) shape: [1, 8, 8, 128]
# PCNBlock_1:
# 	Conv2DTranspose layer output(PCNBlock_1_convT) shape: [1, 16, 16, 64]
# 	Conv2D layer output(PCNBlock_1_conv) shape: [1, 16, 16, 128]
# MaxPool2D layer output(MaxPool_0) shape: [1, 16, 16, 64]
# PCNBlock_0:
# 	Conv2DTranspose layer output(PCNBlock_0_convT) shape: [1, 32, 32, 64]
# 	Conv2D layer output(PCNBlock_0_conv) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D_init) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Epoch 1/30 | Time : 33.22 s | train_loss: 2.3026 | val_loss: 2.3026 | val_acc: 0.1040
#
# Epoch 2/30 | Time : 28.44 s | train_loss: 2.3026 | val_loss: 2.3026 | val_acc: 0.1040
#
# Epoch 3/30 | Time : 28.55 s | train_loss: 2.3026 | val_loss: 2.3026 | val_acc: 0.0952
#
# Epoch 4/30 | Time : 28.31 s | train_loss: 2.3026 | val_loss: 2.3026 | val_acc: 0.0952
#
# Epoch 5/30 | Time : 27.49 s | train_loss: 2.3026 | val_loss: 2.3026 | val_acc: 0.0972
#
# Epoch 6/30 | Time : 27.53 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0972
#
# Epoch 7/30 | Time : 27.55 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0972
#
# Epoch 8/30 | Time : 27.52 s | train_loss: 2.3026 | val_loss: 2.3026 | val_acc: 0.0984
#
# Epoch 9/30 | Time : 27.51 s | train_loss: 2.3026 | val_loss: 2.3026 | val_acc: 0.0952
#
# Epoch 10/30 | Time : 27.52 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0952
#
# Epoch 11/30 | Time : 27.57 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0952
#
# Epoch 12/30 | Time : 27.50 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0952
#
# Epoch 13/30 | Time : 27.49 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0952
#
# Epoch 14/30 | Time : 27.53 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0952
#
# Epoch 15/30 | Time : 27.55 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0952
#
# Epoch 16/30 | Time : 27.49 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0958
#
# Epoch 17/30 | Time : 27.53 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0952
#
# Epoch 18/30 | Time : 27.51 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0958
#
# Epoch 19/30 | Time : 27.50 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0958
#
# Epoch 20/30 | Time : 27.51 s | train_loss: 2.3026 | val_loss: 2.3027 | val_acc: 0.0958
#
# Epoch 21/30 | Time : 27.52 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0958
#
# Epoch 22/30 | Time : 27.52 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0958
#
# Epoch 23/30 | Time : 27.51 s | train_loss: 2.3025 | val_loss: 2.3028 | val_acc: 0.0958
#
# Epoch 24/30 | Time : 27.51 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0958
#
# Epoch 25/30 | Time : 27.51 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0952
#
# Epoch 26/30 | Time : 27.51 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0958
#
# Epoch 27/30 | Time : 27.52 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0958
#
# Epoch 28/30 | Time : 27.53 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0958
#
# Epoch 29/30 | Time : 27.50 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0958
#
# Epoch 30/30 | Time : 27.51 s | train_loss: 2.3026 | val_loss: 2.3028 | val_acc: 0.0976
#
# Finished training after 30 epochs!

# %%
# he_no_gn
cfg1 = configs[1]
print("Training: he_no_gn")

train_loss1, val_loss1, val_acc1 = train_model(
    cfg1["init"],
    cfg1["group_norm"]
)

results["he_no_gn"] = {
    "train_loss": train_loss1,
    "val_loss": val_loss1,
    "val_acc": val_acc1,
}
# Out:
# Training: he_no_gn
# ---------------------------------------------------------------------------
# Dense layer output(Dense_output) shape: [1, 10]
# Dense layer output(Dense_hidden) shape: [1, 128]
# Dropout layer output(Dropout) shape: [1, 3072]
# Flatten layer output(Flatten) shape: [1, 3072]
# MaxPool2D layer output(MaxPool_2) shape: [1, 4, 4, 192]
# PCNBlock_2:
# 	Conv2DTranspose layer output(PCNBlock_2_convT) shape: [1, 8, 8, 128]
# 	Conv2D layer output(PCNBlock_2_conv) shape: [1, 8, 8, 192]
# MaxPool2D layer output(MaxPool_1) shape: [1, 8, 8, 128]
# PCNBlock_1:
# 	Conv2DTranspose layer output(PCNBlock_1_convT) shape: [1, 16, 16, 64]
# 	Conv2D layer output(PCNBlock_1_conv) shape: [1, 16, 16, 128]
# MaxPool2D layer output(MaxPool_0) shape: [1, 16, 16, 64]
# PCNBlock_0:
# 	Conv2DTranspose layer output(PCNBlock_0_convT) shape: [1, 32, 32, 64]
# 	Conv2D layer output(PCNBlock_0_conv) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D_init) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Epoch 1/30 | Time : 31.88 s | train_loss: 13.4808 | val_loss: 2.3003 | val_acc: 0.1064
#
# Epoch 2/30 | Time : 28.13 s | train_loss: 2.2976 | val_loss: 2.2632 | val_acc: 0.1244
#
# Epoch 3/30 | Time : 28.23 s | train_loss: 2.2425 | val_loss: 2.1803 | val_acc: 0.1895
#
# Epoch 4/30 | Time : 28.48 s | train_loss: 2.1316 | val_loss: 2.0161 | val_acc: 0.2644
#
# Epoch 5/30 | Time : 28.61 s | train_loss: 2.0139 | val_loss: 1.8746 | val_acc: 0.3225
#
# Epoch 6/30 | Time : 28.75 s | train_loss: 1.8855 | val_loss: 1.7246 | val_acc: 0.3550
#
# Epoch 7/30 | Time : 28.84 s | train_loss: 1.7585 | val_loss: 1.6339 | val_acc: 0.3942
#
# Epoch 8/30 | Time : 28.84 s | train_loss: 1.6505 | val_loss: 1.5746 | val_acc: 0.4135
#
# Epoch 9/30 | Time : 28.85 s | train_loss: 1.5852 | val_loss: 1.5194 | val_acc: 0.4409
#
# Epoch 10/30 | Time : 28.85 s | train_loss: 1.5129 | val_loss: 1.4661 | val_acc: 0.4700
#
# Epoch 11/30 | Time : 28.86 s | train_loss: 1.4591 | val_loss: 1.4366 | val_acc: 0.4918
#
# Epoch 12/30 | Time : 28.85 s | train_loss: 1.3842 | val_loss: 1.3697 | val_acc: 0.5100
#
# Epoch 13/30 | Time : 28.84 s | train_loss: 1.3287 | val_loss: 1.3370 | val_acc: 0.5184
#
# Epoch 14/30 | Time : 28.86 s | train_loss: 1.2766 | val_loss: 1.2902 | val_acc: 0.5477
#
# Epoch 15/30 | Time : 28.85 s | train_loss: 1.2191 | val_loss: 1.2662 | val_acc: 0.5531
#
# Epoch 16/30 | Time : 28.85 s | train_loss: 1.1752 | val_loss: 1.2197 | val_acc: 0.5707
#
# Epoch 17/30 | Time : 28.85 s | train_loss: 1.1124 | val_loss: 1.1905 | val_acc: 0.5897
#
# Epoch 18/30 | Time : 28.85 s | train_loss: 1.0742 | val_loss: 1.1660 | val_acc: 0.5925
#
# Epoch 19/30 | Time : 28.85 s | train_loss: 1.0278 | val_loss: 1.1409 | val_acc: 0.6140
#
# Epoch 20/30 | Time : 28.85 s | train_loss: 0.9731 | val_loss: 1.1132 | val_acc: 0.6178
#
# Epoch 21/30 | Time : 28.85 s | train_loss: 0.9383 | val_loss: 1.1135 | val_acc: 0.6236
#
# Epoch 22/30 | Time : 28.85 s | train_loss: 0.9013 | val_loss: 1.0835 | val_acc: 0.6318
#
# Epoch 23/30 | Time : 28.86 s | train_loss: 0.8611 | val_loss: 1.0645 | val_acc: 0.6352
#
# Epoch 24/30 | Time : 28.84 s | train_loss: 0.8045 | val_loss: 1.0660 | val_acc: 0.6430
#
# Epoch 25/30 | Time : 28.85 s | train_loss: 0.7692 | val_loss: 1.0340 | val_acc: 0.6504
#
# Epoch 26/30 | Time : 28.85 s | train_loss: 0.7300 | val_loss: 1.0651 | val_acc: 0.6418
#
# Epoch 27/30 | Time : 28.85 s | train_loss: 0.6923 | val_loss: 1.0161 | val_acc: 0.6671
#
# Epoch 28/30 | Time : 28.87 s | train_loss: 0.6704 | val_loss: 1.0212 | val_acc: 0.6617
#
# Epoch 29/30 | Time : 28.87 s | train_loss: 0.6233 | val_loss: 1.0206 | val_acc: 0.6673
#
# Epoch 30/30 | Time : 28.86 s | train_loss: 0.5835 | val_loss: 1.0576 | val_acc: 0.6625
#
# Finished training after 30 epochs!

# %%
import tensorflow as tf
tf.keras.backend.clear_session()
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# %%
# he_gn
cfg2 = configs[2]
print("Training: he_gn")

train_loss2, val_loss2, val_acc2 = train_model(
    cfg2["init"],
    cfg2["group_norm"]
)

results["he_gn"] = {
    "train_loss": train_loss2,
    "val_loss": val_loss2,
    "val_acc": val_acc2,
}
# Out:
# Training: he_gn
# ---------------------------------------------------------------------------
# Dense layer output(Dense_output) shape: [1, 10]
# Dense layer output(Dense_hidden) shape: [1, 128]
# Dropout layer output(Dropout) shape: [1, 3072]
# Flatten layer output(Flatten) shape: [1, 3072]
# MaxPool2D layer output(MaxPool_2) shape: [1, 4, 4, 192]
# PCNBlock_2:
# 	Conv2DTranspose layer output(PCNBlock_2_convT) shape: [1, 8, 8, 128]
# 	Conv2D layer output(PCNBlock_2_conv) shape: [1, 8, 8, 192]
# MaxPool2D layer output(MaxPool_1) shape: [1, 8, 8, 128]
# PCNBlock_1:
# 	Conv2DTranspose layer output(PCNBlock_1_convT) shape: [1, 16, 16, 64]
# 	Conv2D layer output(PCNBlock_1_conv) shape: [1, 16, 16, 128]
# MaxPool2D layer output(MaxPool_0) shape: [1, 16, 16, 64]
# PCNBlock_0:
# 	Conv2DTranspose layer output(PCNBlock_0_convT) shape: [1, 32, 32, 64]
# 	Conv2D layer output(PCNBlock_0_conv) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D_init) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Epoch 1/30 | Time : 100.39 s | train_loss: 2.8193 | val_loss: 1.9332 | val_acc: 0.2951
#
# Epoch 2/30 | Time : 92.50 s | train_loss: 1.9258 | val_loss: 1.6738 | val_acc: 0.3862
#
# Epoch 3/30 | Time : 92.52 s | train_loss: 1.7094 | val_loss: 1.5015 | val_acc: 0.4567
#
# Epoch 4/30 | Time : 92.56 s | train_loss: 1.5419 | val_loss: 1.4010 | val_acc: 0.4944
#
# Epoch 5/30 | Time : 92.56 s | train_loss: 1.4323 | val_loss: 1.3167 | val_acc: 0.5198
#
# Epoch 6/30 | Time : 92.57 s | train_loss: 1.3512 | val_loss: 1.2264 | val_acc: 0.5479
#
# Epoch 7/30 | Time : 92.57 s | train_loss: 1.2638 | val_loss: 1.1808 | val_acc: 0.5655
#
# Epoch 8/30 | Time : 92.59 s | train_loss: 1.1954 | val_loss: 1.1049 | val_acc: 0.6002
#
# Epoch 9/30 | Time : 92.59 s | train_loss: 1.1358 | val_loss: 1.0638 | val_acc: 0.6208
#
# Epoch 10/30 | Time : 92.58 s | train_loss: 1.0749 | val_loss: 1.0083 | val_acc: 0.6388
#
# Epoch 11/30 | Time : 92.56 s | train_loss: 1.0400 | val_loss: 0.9851 | val_acc: 0.6470
#
# Epoch 12/30 | Time : 92.57 s | train_loss: 0.9763 | val_loss: 0.9728 | val_acc: 0.6536
#
# Epoch 13/30 | Time : 92.61 s | train_loss: 0.9407 | val_loss: 0.9974 | val_acc: 0.6534
#
# Epoch 14/30 | Time : 92.58 s | train_loss: 0.9039 | val_loss: 0.9440 | val_acc: 0.6697
#
# Epoch 15/30 | Time : 92.58 s | train_loss: 0.8731 | val_loss: 0.9052 | val_acc: 0.6817
#
# Epoch 16/30 | Time : 92.57 s | train_loss: 0.8426 | val_loss: 0.8885 | val_acc: 0.6937
#
# Epoch 17/30 | Time : 92.56 s | train_loss: 0.8048 | val_loss: 0.8921 | val_acc: 0.6857
#
# Epoch 18/30 | Time : 92.56 s | train_loss: 0.7779 | val_loss: 0.8861 | val_acc: 0.7005
#
# Epoch 19/30 | Time : 92.58 s | train_loss: 0.7526 | val_loss: 0.8970 | val_acc: 0.6865
#
# Epoch 20/30 | Time : 92.58 s | train_loss: 0.7284 | val_loss: 0.8559 | val_acc: 0.7085
#
# Epoch 21/30 | Time : 92.57 s | train_loss: 0.6954 | val_loss: 0.8532 | val_acc: 0.7117
#
# Epoch 22/30 | Time : 92.59 s | train_loss: 0.6712 | val_loss: 0.8307 | val_acc: 0.7157
#
# Epoch 23/30 | Time : 92.57 s | train_loss: 0.6538 | val_loss: 0.8498 | val_acc: 0.7099
#
# Epoch 24/30 | Time : 92.58 s | train_loss: 0.6269 | val_loss: 0.8210 | val_acc: 0.7252
#
# Epoch 25/30 | Time : 92.60 s | train_loss: 0.5975 | val_loss: 0.8206 | val_acc: 0.7212
#
# Epoch 26/30 | Time : 92.58 s | train_loss: 0.5759 | val_loss: 0.8305 | val_acc: 0.7274
#
# Epoch 27/30 | Time : 92.58 s | train_loss: 0.5401 | val_loss: 0.8361 | val_acc: 0.7280
#
# Epoch 28/30 | Time : 92.60 s | train_loss: 0.5306 | val_loss: 0.8225 | val_acc: 0.7308
#
# Epoch 29/30 | Time : 92.57 s | train_loss: 0.5141 | val_loss: 0.8348 | val_acc: 0.7290
#
# Epoch 30/30 | Time : 92.59 s | train_loss: 0.4712 | val_loss: 0.8273 | val_acc: 0.7330
#
# Finished training after 30 epochs!

# %%
plt.figure()

for name in results:
    plt.plot(results[name]["train_loss"], label=name)

plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.title("Training Loss vs Epoch")
plt.legend()
plt.grid()

plt.show()

# %%
plt.figure()

for name in results:
    plt.plot(results[name]["val_loss"], label=name)

plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Epoch")
plt.legend()
plt.grid()

plt.show()

# %%
plt.figure()

for name in results:
    plt.plot(results[name]["val_acc"], label=name)

plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy vs Epoch")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ## Task 10: Build, train, and evaluate larger ConvPCN on CIFAR-10
#
# For fun, let's push the convolutional PCN architecture further and train an even larger net on CIFAR-10 that we will call `ConvPCN7XL` composed of the following:
#
# - 1 solo `Conv2D` layer at the beginning of the network
# - 4 ConvPCNBlocks
# - 1 dense hidden layer
# - 1 output layer
#
# Your goal is to implement and train the network with default hyperparameters (including learning rate) except for the following:
# - batch size of `64`
# - patience of `7`
# - learning rate patience of `3` (`3` max decays)
# - Group norm and He initialization turned on
#
# Make 2 high-quality plots showing
# 1. the training and validation loss over epochs
# 2. the validation acc over epochs
#
# Print out the accuracy on the CIFAR-10 test set.
#
# **Note:** This is expected to take some time to train, likely 60 mins+ on the GPU.
#
#
# *Your network should do VERY well, way better than any network we have explored thus far!* 😊

# %%
from conv_pcn import ConvPCN7XL

# %%
big_model = ConvPCN7XL(
    input_feats_shape=x_train.shape[1:],
    C=10
)
big_model.compile(lr=1e-4)
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(Dense_output) shape: [1, 10]
# Dense layer output(Dense_hidden) shape: [1, 128]
# Dropout layer output(Dropout) shape: [1, 16384]
# Flatten layer output(Flatten) shape: [1, 16384]
# MaxPool2D layer output(MaxPool_3) shape: [1, 8, 8, 256]
# PCNBlock_3:
# 	Conv2DTranspose layer output(PCNBlock_3_convT) shape: [1, 16, 16, 256]
# 	Conv2D layer output(PCNBlock_3_conv) shape: [1, 16, 16, 256]
# MaxPool2D layer output(MaxPool_2) shape: [1, 16, 16, 256]
# PCNBlock_2:
# 	Conv2DTranspose layer output(PCNBlock_2_convT) shape: [1, 32, 32, 128]
# 	Conv2D layer output(PCNBlock_2_conv) shape: [1, 32, 32, 256]
# PCNBlock_1:
# 	Conv2DTranspose layer output(PCNBlock_1_convT) shape: [1, 32, 32, 128]
# 	Conv2D layer output(PCNBlock_1_conv) shape: [1, 32, 32, 128]
# PCNBlock_0:
# 	Conv2DTranspose layer output(PCNBlock_0_convT) shape: [1, 32, 32, 64]
# 	Conv2D layer output(PCNBlock_0_conv) shape: [1, 32, 32, 128]
# Conv2D layer output(Conv2D_init) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------

# %%
train_loss, val_loss, val_acc, _ = big_model.fit(
    x_train, y_train,
    x_val, y_val,
    batch_size=64,
    max_epochs=50,  # will stop early via patience
    patience=7,
    lr_patience=3,
    lr_max_decays=3,
)
# Out:
# Epoch 1/50 | Time : 441.19 s | train_loss: 2.0189 | val_loss: 1.5074 | val_acc: 0.4700
#
# Epoch 2/50 | Time : 429.72 s | train_loss: 1.3477 | val_loss: 1.2064 | val_acc: 0.5785
#
# Epoch 3/50 | Time : 429.61 s | train_loss: 1.1080 | val_loss: 1.0270 | val_acc: 0.6456
#
# Epoch 4/50 | Time : 429.69 s | train_loss: 0.9497 | val_loss: 0.9466 | val_acc: 0.6729
#
# Epoch 5/50 | Time : 429.78 s | train_loss: 0.8358 | val_loss: 0.8950 | val_acc: 0.6871
#
# Epoch 6/50 | Time : 429.69 s | train_loss: 0.7460 | val_loss: 0.8558 | val_acc: 0.7155
#
# Epoch 7/50 | Time : 429.76 s | train_loss: 0.6773 | val_loss: 0.8670 | val_acc: 0.7123
#
# Epoch 8/50 | Time : 429.76 s | train_loss: 0.5981 | val_loss: 0.8686 | val_acc: 0.7173
#
# Epoch 9/50 | Time : 429.81 s | train_loss: 0.5286 | val_loss: 0.8617 | val_acc: 0.7270
# Learning rate decayed from 0.000100 to 0.000050.
#  | LR decayed. Total decays: 1
# Epoch 10/50 | Time : 429.77 s | train_loss: 0.3931 | val_loss: 0.8301 | val_acc: 0.7438
#
# Epoch 11/50 | Time : 429.76 s | train_loss: 0.3529 | val_loss: 0.8281 | val_acc: 0.7366
#
# Epoch 12/50 | Time : 429.74 s | train_loss: 0.2971 | val_loss: 0.8361 | val_acc: 0.7430
#
# Epoch 13/50 | Time : 429.75 s | train_loss: 0.2647 | val_loss: 0.8783 | val_acc: 0.7448
#
# Epoch 14/50 | Time : 429.86 s | train_loss: 0.2396 | val_loss: 0.8435 | val_acc: 0.7534
# Learning rate decayed from 0.000050 to 0.000025.
#  | LR decayed. Total decays: 2
# Epoch 15/50 | Time : 429.75 s | train_loss: 0.1847 | val_loss: 0.8093 | val_acc: 0.7648
#
# Epoch 16/50 | Time : 429.72 s | train_loss: 0.1624 | val_loss: 0.8341 | val_acc: 0.7586
#
# Epoch 17/50 | Time : 429.70 s | train_loss: 0.1451 | val_loss: 0.8394 | val_acc: 0.7618
#
# Epoch 18/50 | Time : 429.74 s | train_loss: 0.1314 | val_loss: 0.8485 | val_acc: 0.7640
# Learning rate decayed from 0.000025 to 0.000012.
#  | LR decayed. Total decays: 3
# Epoch 19/50 | Time : 429.75 s | train_loss: 0.1091 | val_loss: 0.8391 | val_acc: 0.7670
#
# Epoch 20/50 | Time : 429.81 s | train_loss: 0.1004 | val_loss: 0.8558 | val_acc: 0.7632
#
# Epoch 21/50 | Time : 429.77 s | train_loss: 0.0948 | val_loss: 0.8517 | val_acc: 0.7648
#
# Epoch 22/50 | Time : 429.80 s | train_loss: 0.0891 | val_loss: 0.8661 | val_acc: 0.7678
#
# Early stopping triggered. Stopping training.
# Finished training after 22 epochs!

# %%
plt.figure()

plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Val Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid()

plt.show()

# %%
plt.figure()

plt.plot(val_acc, label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid()

plt.show()

# %%
test_acc = model.evaluate(x_test, y_test)

print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-26-4119400791.py in <cell line: 0>()
# ----> 1 test_acc = model.evaluate(x_test, y_test)
#       2
#       3 print(f"Test Accuracy: {test_acc:.4f}")
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Extensions
#
# ### General guidelines
#
# 1. Never integrate extensions into your base project so that they change the expected behavior of core functions. If your extension changes the core design/behavior, no problem, duplicate your working base project and add features from there.
# 2. Check the rubric to keep in mind how extensions on this project will be graded.
# 3. While I may consult your code and "written log" of what you did, **I am grading your extensions based on what you present in your 3-5 min video.**
# 3. I suggest documenting your explorations in a "log" or "lab notebook" style (i.e. documenting your thought/progression/discovery/learning process). I'm not grading your writing, so you can keep it succinct. **Whatever is most useful to you to remember what you did.**
# 4. I suggest taking a hypothesis driven approach. For example "I was curious about X so I explored Y. I found Z, which was not what I expected because..., so then tried A..."
# 5. Make plots to help showcase your results.
# 6. **More is not necessarily better.** Generally, a small number of "in-depth" extensions count for more than many "shallow" extensions.
#
# ### AI guidelines
#
# You may use AI in mostly any capacity for extensions. However, keep in mind:
# 1. There is no need to use AI at all!
# 2. You are welcome to use AI as a tool (e.g. automate something that is tedious, help you get unstuck, etc.). However, you should be coding, you should be thinking, you should be writing, you should be creating. If you are spending most (or even close to most) of your time typing into a chatbot and copy-pasting, you have probably gone too far with AI use.
# 3. I don't find large volumes of AI generated code/text/plots to be particularly impressive and you risk losing my interest while grading. Remember: I'm grading your extensions based on your video presentation. **More is not necessarily better.**
#
# ### Video guidelines
#
# 1. Please try to keep your video to 5 minutes (*I have other projects to grade!*). If you turn in a longer video, I make no promise that I will watch more than 5 minutes.
# 2. Your screen should be shared as you show me what you did. A live video of your face should also appear somewhere on the screen (e.g. picture-in-picture overlay / split screen).
# 3. Your partner should join you for the video and take turns talking, but, if necessary, it is fine to have one team member present during the record the video.
# 4. Do not simply read text from your notebook, do not read from a prepared script. I am not grading how polished your video presentation is (see extension grading criteria on rubric).
# 5. I am looking for original and creative explorations sparked by your curiosity/interest/passion in a topic. This should be apparent in your video.
# 6. Be natural,, don't feel the need to impress me with fancy language. If it is helpful, imagine that we are talking one-on-one about your extension. Tell me what you did :)
#
# ### Extension ideas

# %% [markdown]
# #### 1. Explore other image completion scenarios
#
# Explore the generative capability of the dense PCN more thoroughly by examining:
# - quality of reconstruction when more/less is masked away.
# - introduce different types of masks (e.g. horizontal, periodic stripes, etc.)
# - try masking a random selection pixels. Analyze reconstruction with different proportions of the image that is masked out.
# - try reconstructing image when random noise is added to the masked locations. Analyze reconstruction with different noise amounts/strengths.

# %% [markdown]
# #### 2. Nonlinearities in the dense PCN
#
# *This is a challenging extension.*
#
# The dense PCN is an entirely linear model. Modify the architecture to try different ways to incorporate nonlinearities (e.g. ReLU).
#
# *This requires more thought than it might initially seem since ReLU 0s out signals and so they cannot be directly used to predict the signal below...*

# %% [markdown]
# #### 3. Dense PCN depth
#
# You build a modular, extendable dense PCN, but in the base project we only considered nets with a single hidden layer. Run experiments to analyze how different depths/numbers of units affects classification accuracy, quality of dreaming, or quality of image completion.

# %% [markdown]
# #### 4. Hyperparameter exploration with ConvPCN
#
# Can you find hyperparameters that produce even better CIFAR-10 validation accuracy?
#
# *Given how time intensive it is to train the ConvPCNs I would suggest running focused experiments to analyze the effect of one/several hyperparameter while keeping most kept at default values.*

# %% [markdown]
# #### 5. Datasets of your choice
#
# Train either the dense or convolutional PCN on a dataset of your choice. Characterize the accuracy or generative capabilities on your dataset.
#
# Some good ones:
# - MNIST
# - Fashion MNIST
# - CIFAR-100 (like CIFAR-10 but with 100 classes)

# %% [markdown]
# #### 6. Prediction error passes in the ConvPCN
#
# Run an experiment that varies the number of steps for which each block attempts to minimize the local prediction error. Is there an optimal number?

# %% [markdown]
# #### 7. Modifying the ConvPCN architecture
#
# Experiment with making changes to the ConvPCN architecture (add/remove max pooling layers, etc.).

# %% [markdown]
# #### 8. Runtime vs accuracy
#
# Now that you have a high performing network try to build shallower/smaller networks that achieve as close accuracy to the deeper/larger ones, but train substantially faster. What trade offs do you make? How much does accuracy drop? How much time can you save?
